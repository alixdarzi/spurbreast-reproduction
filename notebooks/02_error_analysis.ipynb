# %% [markdown]
# # Error analysis
# Load a locked run's ignored `predictions.csv` and stratify errors by field strength and patient. No model logic is duplicated here.

# %%
from pathlib import Path
import pandas as pd
prediction_file = Path('../results/<locked-run-id>/predictions.csv')
# predictions = pd.read_csv(prediction_file)
