# %% [markdown]
# # SpurBreast data audit
# Run `scripts/prepare_data.py` first. This notebook only presents the generated aggregate audit.

# %%
import json
from pathlib import Path
audit = json.loads(Path('../reports/tables/data_audit_summary.json').read_text())
audit
